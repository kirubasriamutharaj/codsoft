# %% [markdown]
# <a href="https://colab.research.google.com/github/kirubasriamutharaj/codsoft/blob/main/TASK_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit.learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
import pandas as pd
data = pd.read_csv("advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.shape
# Out:
# (200, 4)

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# CORREALTION MATRIX
# data.corr()
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
# DATA VISUALIZATION
# HISTOGRAM
data['Sales'].hist()
plt.title('Sales distribution')
plt.show()

# %%
# BOXPLOT
sns.boxplot(data['Sales'])
plt.show()

# %%
#PAIRPLOT
sns.pairplot(data)
plt.show()

# %%
sns.scatterplot(x='TV', y='Sales', data=data)
plt.title('Sales vs TV Advertising')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.show()

# %%
TV ADVERSTING GREATLY INFULENCES THE SALES

# %%
import pandas as pd
data = pd.read_csv("advertising.csv")
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(data[['TV']],data[['Sales']],test_size = 0.3,random_state =0)

# %%
print(x_train)
# Out:
#         TV
# 131  265.2
# 96   197.6
# 181  218.5
# 19   147.3
# 153  171.3
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131   17.7
# 96    16.7
# 181   17.2
# 19    14.6
# 153   16.0
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [140 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred = model.predict(x_train)

# %%
print(y_pred)
# Out:
# [11.3  11.6  10.6  17.8  16.   11.8   5.7  20.9   9.5  16.7  20.2  12.9
#  16.5  19.7   9.4  14.2  17.7   3.2  12.6  21.7  20.9  10.3  17.1  16.
#  11.8  11.6  17.5  19.   16.6   9.5   9.7  18.3  19.8  25.4   5.3   7.
#  11.8  21.2  11.3   9.5  10.9   7.3  15.5  18.4  17.4  10.7   5.7   8.95
#  11.   11.5  16.7  22.1  19.8  20.7  10.4  12.6  20.7  16.   19.    6.6 ]

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_test,color='green')
